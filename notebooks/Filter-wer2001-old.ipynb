# %% [markdown]
# # Example `fdesign` GPR

# %%
import numpy as np
import matplotlib.pyplot as plt

from empymod import dipole, utils
from empyscripts import fdesign

# Set minimum offset to 1e-20
# empymod version 1.4.5 or higher is required!
utils.set_minimum(min_off=1e-20)


# %matplotlib inline
plt.style.use('seaborn-notebook')

# %% [markdown]
# ## $f_I$, $f_C$

# %%
model1 = {
    'zsrc': 0,
    'zrec': 1,
    'res': 200,
    'aniso': 1,
    'freqtime': 250e6,
    'epermH': 10,
    'epermV': 10,
    'mpermH': 1,
    'mpermV': 1,
}

model2 = {
    'zsrc': 0.0000001,
    'zrec': 0.5, 
    'depth': [0, 1],
    'res': [2e14, 200, 20] ,
    'freqtime': 850e6,
    'epermH': [1, 9, 15],
    'epermV': [1, 9, 15],
    'verbrhs': 0,
    'verblhs': 0
}

# %% [markdown]
# ## Calculation

# %%
inp = {'spacing': (0.006, .007, 10),
       'shift': (1, 2.5, 10),
       'r': np.logspace(0, 1, 100),
       'r_def': (1, 1, 2),
       'full_output': True, #       'finish': True,
       'cvar': 'r',
       'save': False, #True,
       'fI': fdesign.empy_hankel(['j0', 'j1'], **model1),
       'fC': fdesign.empy_hankel('j2', **model2)}
# filt, out = fdesign.design(n=2001, name='wer2001-old', plot=2, **inp)
filt, out = fdesign.load_filter('wer2001-old', True)
fdesign.plot_result(filt, out, 'r', True)
# Out:
#    Filter length   : 2001
#    Best filter
#    > Max r         : 2.98365
#    > Spacing       : 0.006111111111
#    > Shift         : 1
#    > Base min/max  : 6.029380e-03 / 1.225508e+03

# %% [markdown]
# ## Plot all frequencies, fixed offset

# %%
f = np.arange(10, 85+1)*1e7
inp1 = {
    'src': [0, 0, 0.0000001],
    'rec': [4, 0, 0.5], 
    'depth': [0, 1],
    'res': [2e14, 200, 20] ,
    'ab': 11,
    'freqtime': f,
    'epermH': [1, 9, 15],
    'epermV': [1, 9, 15],
    'verb': 1,
}

dlf = dipole(htarg=filt, xdirect=False, **inp1)
qwe = dipole(ht='qwe', htarg=[1e-8, 1e-15, '', 200, 200, 60, 1e-6, 160, 4000], **inp1)

plt.figure(figsize=(15, 5))
plt.subplot(121)
plt.grid('on')
plt.title(r'Amplitude; $r=4\,$m')
plt.plot(f/1e6, qwe.real, 'k', lw=3, label='Re(QWE)')
plt.plot(f/1e6, dlf.real, 'r--', label='Re(DLF)')
plt.plot(f/1e6, qwe.imag, 'b', lw=3, label='Im(QWE)')
plt.plot(f/1e6, dlf.imag, 'c--', label='Im(DLF)')
plt.xlabel('Frequency (MHz)')
plt.legend()

plt.subplot(122)
plt.grid('on')
plt.title('Relative error')
plt.semilogy(f/1e6, np.abs((dlf.real-qwe.real)/qwe.real), 'r:', label='Re')
plt.semilogy(f/1e6, np.abs((dlf.imag-qwe.imag)/qwe.imag), 'b:', label='Im')
plt.semilogy(f/1e6, np.abs((dlf-qwe)/qwe), 'k', label='Abs')
plt.legend()
plt.xlabel('Frequency (MHz)')

plt.show()

# %% [markdown]
# ## Plot full offset range, fixed frequency

# %%
x = np.arange(10, 200)*.02
inp2 = {
    'src': [0, 0, 0.0000001],
    'rec': [x, x*0, 0.5], 
    'depth': [0, 1],
    'res': [2e14, 200, 20] ,
    'ab': 11,
    'freqtime': 850e6,
    'epermH': [1, 9, 15],
    'epermV': [1, 9, 15],
    'verb': 1,
}

dlf = dipole(htarg=filt, xdirect=False, **inp2)
qwe = dipole(ht='qwe', htarg=[1e-8, 1e-15, '', 200, 200, 60, 1e-6, 160, 4000], **inp2)

plt.figure(figsize=(15, 5))
plt.subplot(121)
plt.grid('on')
plt.title(r'Amplitude; $f=850\,$MHz')

plt.semilogy(x, np.abs(qwe), 'k', lw=3, label='QWE')
plt.semilogy(x, np.abs(dlf), 'r--', label='DLF')
plt.legend()
plt.xlabel('Offset (m)')

plt.subplot(122)
plt.grid('on')
plt.title('Relative error')
plt.semilogy(x, np.abs((dlf-qwe)/qwe), 'k')
plt.xlabel('Offset (m)')

plt.show()

# %%
import printinfo
printinfo.info()
# Out:
# <h3>Mon Dec 18 21:53:18 2017 CST</h3><table><tr style='border: 2px solid #fff; text-align: left;'><td style='background-color: #ccc;width: 10%; border: 2px solid #fff;'>1.4.5dev0</td><td style='border: 2px solid #fff; text-align: left;'>empymod</td><td style='background-color: #ccc;width: 10%; border: 2px solid #fff;'>Linux</td><td style='border: 2px solid #fff; text-align: left;'>OS</td><td style='background-color: #ccc;width: 10%; border: 2px solid #fff;'>4</td><td style='border: 2px solid #fff; text-align: left;'>CPU(s)</td><td style='background-color: #ccc;width: 10%; border: 2px solid #fff;'>6.1.0</td><td style='border: 2px solid #fff; text-align: left;'>IPython</td></tr><tr style='border: 2px solid #fff; text-align: left;'><td style='background-color: #ccc;width: 10%; border: 2px solid #fff;'>1.13.1</td><td style='border: 2px solid #fff; text-align: left;'>numpy</td><td style='background-color: #ccc;width: 10%; border: 2px solid #fff;'>0.19.1</td><td style='border: 2px solid #fff; text-align: left;'>scipy</td><td style='background-color: #ccc;width: 10%; border: 2px solid #fff;'>2.6.2</td><td style='border: 2px solid #fff; text-align: left;'>numexpr</td><td style='background-color: #ccc;width: 10%; border: 2px solid #fff;'>2.0.2</td><td style='border: 2px solid #fff; text-align: left;'>matplotlib</td></tr><tr style='border: 2px solid #fff; text-align: left;'><td style='border: 2px solid #fff; text-align: left;' colspan='8'>3.6.2 |Anaconda, Inc.| (default, Sep 30 2017, 18:42:57)
# [GCC 7.2.0]</td></tr><tr style='background-color: #ccc;width: 10%; border: 2px solid #fff;'><td style='background-color: #ccc;width: 10%; border: 2px solid #fff;' colspan='8'>None</td></tr></table>
