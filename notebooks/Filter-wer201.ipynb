# %% [markdown]
# # Filter `wer201`

# %%
import numpy as np
import matplotlib.pyplot as plt

from empymod import dipole
from empyscripts import fdesign

# %matplotlib inline
plt.style.use('seaborn-notebook')

# %%
inp = {'r': np.logspace(0, 10, 1000),
       'r_def': (1, 1, 2),
       'n': 201,
       'name': 'test',
       'full_output': True,
       'fI': (fdesign.j0_1(5), fdesign.j1_1(5))}

# %% [markdown]
# ## 1. Rough overview over a wide range

# %%
filt1, out1 = fdesign.design(spacing=(0.01, 0.2, 10), shift=(-4, 0, 10), save=False, **inp)
# Out:
#    brute fct calls : 100
#
#    Filter length   : 201
#    Best filter
#    > Min field     : 1.67408e-14
#    > Spacing       : 0.07333333333
#    > Shift         : -2.222222222
#    > Base min/max  : 7.080680e-05 / 1.658545e+02
#
# :: empymod END; runtime = 0:00:01.455768 ::
#
# * QC: Overview of brute-force inversion:

# %% [markdown]
# ## 2. First focus

# %%
filt2, out2 = fdesign.design(spacing=(0.04, 0.1, 10), shift=(-3, -0.5, 10), save=False, **inp)
# Out:
#    brute fct calls : 100
#
#    Filter length   : 201
#    Best filter
#    > Min field     : 1.99117e-16
#    > Spacing       : 0.06
#    > Shift         : -1.333333333
#    > Base min/max  : 6.533920e-04 / 1.063427e+02
#
# :: empymod END; runtime = 0:00:01.451022 ::
#
# * QC: Overview of brute-force inversion:

# %% [markdown]
# ## 3. Final focus

# %%
filt, out = fdesign.design(spacing=(0.047, 0.08, 10), shift=(-2.4, -0.75, 10), finish=True, save=False, **inp)
# Out:
#    brute fct calls : 100
#    fmin  fct calls : 261
#
#    Filter length   : 201
#    Best filter
#    > Min field     : 7.48825e-17
#    > Spacing       : 0.05960681365
#    > Shift         : -1.300029438
#    > Base min/max  : 7.026084e-04 / 1.057050e+02
#
# :: empymod END; runtime = 0:00:05.080710 ::
#
# * QC: Overview of brute-force inversion:

# %%
## To reproduce exactil the same filter as wer_201_2018:
# filt_orig, out_orig = fdesign.load_filter('wer201', True)
# fdesign.plot_result(filt_orig, out_orig)
# filt_orig, out_orig = fdesign.design(spacing=out_orig[0][0], shift=out_orig[0][1], **inp)

# %%
def plotresult(depth, res, zsrc, zrec):
    x = np.arange(1, 101)*200
    inp = {
        'src': [0, 0, depth[1]-zsrc],
        'rec': [x, x*0, depth[1]-zrec], 
        'depth': depth,
        'res': res,
        'ab': 11,
        'freqtime': 1,
        'verb': 1,
    }
    
    kong241 = dipole(htarg='kong_241_2007', **inp)
    key201 = dipole(htarg='key_201_2012', **inp)
    and801 = dipole(htarg='anderson_801_1982', **inp)
    test = dipole(htarg=filt, **inp)
    wer201 = dipole(htarg='wer_201_2018', **inp)
    qwe = dipole(ht='qwe', **inp)
    
    plt.figure(figsize=(15, 5))
    plt.subplot(121)
    plt.grid('on')
    plt.semilogy(x, np.abs(qwe), c='0.5', label='QWE')
    plt.semilogy(x, np.abs(kong241), 'k--', label='Kong241')
    plt.semilogy(x, np.abs(key201), 'k:', label='Key201')
    plt.semilogy(x, np.abs(and801), 'k-.', label='And801')
    plt.semilogy(x, np.abs(test), 'r', label='This filter')
    plt.semilogy(x, np.abs(wer201), 'b', label='Wer201')
    plt.legend()
    plt.xticks([0, 5e3, 10e3, 15e3, 20e3])
    plt.xlim([0, 20e3])
    
    plt.subplot(122)
    plt.grid('on')
    plt.semilogy(x, np.abs((kong241-qwe)/qwe), 'k--', label='Kong241')
    plt.semilogy(x, np.abs((key201-qwe)/qwe), 'k:', label='Key201')
    plt.semilogy(x, np.abs((and801-qwe)/qwe), 'k-.', label='And801')
    plt.semilogy(x, np.abs((test-qwe)/qwe), 'r', label='This filter')
    plt.semilogy(x, np.abs((wer201-qwe)/qwe), 'b', label='Wer201')
    plt.legend()
    plt.xticks([0, 5e3, 10e3, 15e3, 20e3])
    plt.xlim([0, 20e3])
    plt.ylim([1e-14, 1])
    
    plt.show()

plotresult([-1e50, 2000,], [2e14, 1/3.2, 1], 50, 0)  # KONG model
plotresult([0, 1000, 2000, 2100], [1/1e-12, 1/3.3, 1, 100, 1], 10, 0)  # KEY model
plotresult([0, 1, 1000, 1100], [2e14, 10, 10, 500, 10], 0.5, 0.2)  # LAND model
# Out:
# * WARNING :: Hankel-quadrature did not converge at least once;
#              => desired `atol` and `rtol` might not be achieved.
# * WARNING :: Hankel-quadrature did not converge at least once;
#              => desired `atol` and `rtol` might not be achieved.

# %%
from empyscripts import versions
versions('HTML')
# Out:
# <table style='border: 3px solid #ddd;'>
#   <tr>
#     <td style='background-color: #ccc; border: 2px solid #fff;'>Linux</td>
#     <td style='border: 2px solid #fff; text-align: left;'>OS</td>
#     <td style='background-color: #ccc; border: 2px solid #fff;'>8</td>
#     <td style='border: 2px solid #fff; text-align: left;'>CPU(s)</td>
#     <td style='background-color: #ccc; border: 2px solid #fff;'>1.14.0</td>
#     <td style='border: 2px solid #fff; text-align: left;'>numpy</td>
#   </tr>
#   <tr style='border: 2px solid #fff; text-align: left;'>
#     <td style='background-color: #ccc; border: 2px solid #fff;'>1.0.0</td>
#     <td style='border: 2px solid #fff; text-align: left;'>scipy</td>
#     <td style='background-color: #ccc; border: 2px solid #fff;'>1.5.0</td>
#     <td style='border: 2px solid #fff; text-align: left;'>empymod</td>
#     <td style='background-color: #ccc; border: 2px solid #fff;'>0.3.0</td>
#     <td style='border: 2px solid #fff; text-align: left;'>empyscripts</td>
#   </tr>
#   <tr style='border: 2px solid #fff; text-align: left;'>
#     <td style='background-color: #ccc; border: 2px solid #fff;'>6.2.1</td>
#     <td style='border: 2px solid #fff; text-align: left;'>IPython</td>
#     <td style='background-color: #ccc; border: 2px solid #fff;'>2.6.4</td>
#     <td style='border: 2px solid #fff; text-align: left;'>numexpr</td>
#     <td style='background-color: #ccc; border: 2px solid #fff;'>2.1.2</td>
#     <td style='border: 2px solid #fff; text-align: left;'>matplotlib</td>
#   </tr>
#   <tr>
#      <td style='border: 2px solid #fff; text-align: left;' colspan='6'>3.6.4 |Anaconda, Inc.| (default, Jan 16 2018, 18:10:19)
# [GCC 7.2.0]</td>
#   </tr>
#   <tr>
#      <td style='border: 2px solid #fff; text-align: left;' colspan='6'>Intel(R) Math Kernel Library Version 2018.0.1 Product Build 20171007 for Intel(R) 64 architecture applications</td>
#   </tr>
#   <tr>
#      <td style='border: 2px solid #fff; text-align: left;' colspan='6'>Thu Feb 22 08:56:11 2018 CST</td>
#   </tr>
# </table>
